# %%
import pandas as pd

###
csv_import1 = 'forecast_State_Zhvi_1bedroom.csv'
data1 = pd.read_csv(csv_import1, header = None)

data1.at[0, 0] = 'State'
data1.set_index(0, inplace = True)
state = data1.T.iloc[:51,0]
state = list(state)

data1 = data1.T
data1 = data1.iloc[51:,290:]

empty_list = []
for i in range(51):
    empty_list.append("1bedroom")

data1.insert(0, "State", state)
data1.insert(1, "Room Size", empty_list)
###
csv_import2 = 'forecast_State_Zhvi_2bedroom.csv'
data2 = pd.read_csv(csv_import2, header = None)

data2.at[0, 0] = 'State'
data2.set_index(0, inplace = True)
state = data2.T.iloc[:51,0]
state = list(state)

data2 = data2.T
data2 = data2.iloc[51:,290:]

empty_list = []
for i in range(51):
    empty_list.append("2bedroom")

data2.insert(0, "State", state)
data2.insert(1, "Room Size", empty_list)
###
csv_import3 = 'forecast_State_Zhvi_3bedroom.csv'
data3 = pd.read_csv(csv_import3, header = None)

data3.at[0, 0] = 'State'
data3.set_index(0, inplace = True)
state = data3.T.iloc[:51,0]
state = list(state)

data3 = data3.T
data3 = data3.iloc[51:,290:]

empty_list = []
for i in range(51):
    empty_list.append("3bedroom")

data3.insert(0, "State", state)
data3.insert(1, "Room Size", empty_list)
###
csv_import4 = 'forecast_State_Zhvi_4bedroom.csv'
data4 = pd.read_csv(csv_import4, header = None)

data4.at[0, 0] = 'State'
data4.set_index(0, inplace = True)
state = data4.T.iloc[:51,0]
state = list(state)

data4 = data4.T
data4 = data4.iloc[51:,290:]

empty_list = []
for i in range(51):
    empty_list.append("4bedroom")

data4.insert(0, "State", state)
data4.insert(1, "Room Size", empty_list)
###
csv_import5 = 'forecast_State_Zhvi_5BedroomOrMore.csv'
data5 = pd.read_csv(csv_import5, header = None)

data5.at[0, 0] = 'State'
data5.set_index(0, inplace = True)
state = data5.T.iloc[:51,0]
state = list(state)

data5 = data5.T
data5 = data5.iloc[51:,290:]

empty_list = []
for i in range(51):
    empty_list.append("5bedroomOrMore")

data5.insert(0, "State", state)
data5.insert(1, "Room Size", empty_list)
###

states = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}

result = pd.concat([data1,data2,data3,data4,data5])
result = result.drop(result.columns[2:4], axis=1)
result.reset_index(drop=True, inplace=True)
for i in result.index:
    result.at[i, "State"] = states[result.iloc[i,0]]

for col in list((result.columns[2:])):
    result.rename(columns={col:pd.to_datetime(col).strftime("%m/%d/%y")},inplace=True)    

result.to_csv("forecast_total.csv", index = False)
